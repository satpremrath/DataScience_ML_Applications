# %% [markdown]
# <a href="https://colab.research.google.com/github/satpremrath/DataScience_ML_Applications/blob/master/LSTM_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./MSFT.csv', parse_dates= True)
print(f"Shape of the dataset: {df.shape}")
df.head()
# Out:
# Shape of the dataset: (9083, 7)
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061434  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063628   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.064725   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063079    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.061982    47894400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9083 entries, 0 to 9082
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9083 non-null   object
#  1   Open       9083 non-null   float64
#  2   High       9083 non-null   float64
#  3   Low        9083 non-null   float64
#  4   Close      9083 non-null   float64
#  5   Adj Close  9083 non-null   float64
#  6   Volume     9083 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 496.9+ KB

# %%
df.drop(['Open', 'High','Low','Adj Close','Volume'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df.head()
# Out:
#         Date     Close
# 0 1986-03-13  0.097222
# 1 1986-03-14  0.100694
# 2 1986-03-17  0.102431
# 3 1986-03-18  0.099826
# 4 1986-03-19  0.098090

# %%
df.set_index('Date', inplace = True)

# %%
df.head()
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090

# %%
df.Close.plot();

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 116ms/step - loss: 84804.8125 - mean_absolute_error: 289.4721 - val_loss: 92507.3906 - val_mean_absolute_error: 304.0632
# Epoch 2/100
# 7/7 [==============================] - 0s 11ms/step - loss: 84582.2188 - mean_absolute_error: 289.0884 - val_loss: 92312.8984 - val_mean_absolute_error: 303.7432
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 84408.6875 - mean_absolute_error: 288.7874 - val_loss: 92124.5938 - val_mean_absolute_error: 303.4330
# Epoch 4/100
# 7/7 [==============================] - 0s 12ms/step - loss: 84212.6250 - mean_absolute_error: 288.4482 - val_loss: 91876.0000 - val_mean_absolute_error: 303.0231
# Epoch 5/100
# 7/7 [==============================] - 0s 11ms/step - loss: 83928.3359 - mean_absolute_error: 287.9563 - val_loss: 91495.6172 - val_mean_absolute_error: 302.3948
# Epoch 6/100
# 7/7 [==============================] - 0s 10ms/step - loss: 83518.1719 - mean_absolute_error: 287.2410 - val_loss: 90959.8203 - val_mean_absolute_error: 301.5076
# Epoch 7/100
# 7/7 [==============================] - 0s 10ms/step - loss: 82908.4609 - mean_absolute_error: 286.1740 - val_loss: 90110.7500 - val_mean_absolute_error: 300.0963
# Epoch 8/100
# 7/7 [==============================] - 0s 10ms/step - loss: 81963.9688 - mean_absolute_error: 284.5236 - val_loss: 88848.4297 - val_mean_absolute_error: 297.9856
# Epoch 9/100
# 7/7 [==============================] - 0s 10ms/step - loss: 80627.9219 - mean_absolute_error: 282.1607 - val_loss: 87377.2422 - val_mean_absolute_error: 295.5068
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 79247.0312 - mean_absolute_error: 279.7036 - val_loss: 85749.3125 - val_mean_absolute_error: 292.7392
# Epoch 11/100
# 7/7 [==============================] - 0s 11ms/step - loss: 77423.5547 - mean_absolute_error: 276.4258 - val_loss: 83515.8516 - val_mean_absolute_error: 288.8993
# Epoch 12/100
# 7/7 [==============================] - 0s 10ms/step - loss: 75181.6484 - mean_absolute_error: 272.3402 - val_loss: 80851.5312 - val_mean_absolute_error: 284.2508
# Epoch 13/100
# 7/7 [==============================] - 0s 12ms/step - loss: 72531.8594 - mean_absolute_error: 267.4321 - val_loss: 77869.4453 - val_mean_absolute_error: 278.9561
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 69623.1641 - mean_absolute_error: 261.9384 - val_loss: 74587.6797 - val_mean_absolute_error: 273.0104
# Epoch 15/100
# 7/7 [==============================] - 0s 10ms/step - loss: 66297.1797 - mean_absolute_error: 255.4955 - val_loss: 70588.0703 - val_mean_absolute_error: 265.5844
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 62299.2148 - mean_absolute_error: 247.5488 - val_loss: 66071.8672 - val_mean_absolute_error: 256.9413
# Epoch 17/100
# 7/7 [==============================] - 0s 10ms/step - loss: 57774.9688 - mean_absolute_error: 238.2434 - val_loss: 60869.9453 - val_mean_absolute_error: 246.6109
# Epoch 18/100
# 7/7 [==============================] - 0s 10ms/step - loss: 52732.3086 - mean_absolute_error: 227.4339 - val_loss: 55173.9688 - val_mean_absolute_error: 234.7786
# Epoch 19/100
# 7/7 [==============================] - 0s 12ms/step - loss: 47316.0586 - mean_absolute_error: 215.1684 - val_loss: 49308.1250 - val_mean_absolute_error: 221.9350
# Epoch 20/100
# 7/7 [==============================] - 0s 15ms/step - loss: 41817.5469 - mean_absolute_error: 201.9657 - val_loss: 43389.5117 - val_mean_absolute_error: 208.1743
# Epoch 21/100
# 7/7 [==============================] - 0s 12ms/step - loss: 36250.0820 - mean_absolute_error: 187.6577 - val_loss: 37270.8906 - val_mean_absolute_error: 192.9194
# Epoch 22/100
# 7/7 [==============================] - 0s 14ms/step - loss: 30635.8574 - mean_absolute_error: 172.1323 - val_loss: 31412.5430 - val_mean_absolute_error: 177.0863
# Epoch 23/100
# 7/7 [==============================] - 0s 13ms/step - loss: 25360.4160 - mean_absolute_error: 156.0311 - val_loss: 25830.0332 - val_mean_absolute_error: 160.5524
# Epoch 24/100
# 7/7 [==============================] - 0s 16ms/step - loss: 20397.4395 - mean_absolute_error: 139.2550 - val_loss: 20624.8945 - val_mean_absolute_error: 143.4290
# Epoch 25/100
# 7/7 [==============================] - 0s 15ms/step - loss: 15774.7471 - mean_absolute_error: 121.5011 - val_loss: 15252.5234 - val_mean_absolute_error: 123.2847
# Epoch 26/100
# 7/7 [==============================] - 0s 12ms/step - loss: 11108.0098 - mean_absolute_error: 100.4106 - val_loss: 10780.5820 - val_mean_absolute_error: 103.5742
# Epoch 27/100
# 7/7 [==============================] - 0s 12ms/step - loss: 7778.1270 - mean_absolute_error: 81.9855 - val_loss: 7455.8306 - val_mean_absolute_error: 86.0399
# Epoch 28/100
# 7/7 [==============================] - 0s 12ms/step - loss: 5254.5454 - mean_absolute_error: 64.9224 - val_loss: 4934.3223 - val_mean_absolute_error: 69.8667
# Epoch 29/100
# 7/7 [==============================] - 0s 12ms/step - loss: 3449.5330 - mean_absolute_error: 49.8105 - val_loss: 3144.9041 - val_mean_absolute_error: 55.6052
# Epoch 30/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2301.3303 - mean_absolute_error: 38.6285 - val_loss: 1920.5980 - val_mean_absolute_error: 43.2161
# Epoch 31/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1627.5017 - mean_absolute_error: 33.0250 - val_loss: 1155.7842 - val_mean_absolute_error: 33.2087
# Epoch 32/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1259.2670 - mean_absolute_error: 29.9174 - val_loss: 718.7009 - val_mean_absolute_error: 25.8019
# Epoch 33/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1089.8632 - mean_absolute_error: 27.9259 - val_loss: 482.4409 - val_mean_absolute_error: 20.7238
# Epoch 34/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1031.6130 - mean_absolute_error: 27.1678 - val_loss: 348.9606 - val_mean_absolute_error: 17.2045
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.6688 - mean_absolute_error: 26.8715 - val_loss: 279.8982 - val_mean_absolute_error: 15.1170
# Epoch 36/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1012.2452 - mean_absolute_error: 26.8821 - val_loss: 243.9716 - val_mean_absolute_error: 13.9727
# Epoch 37/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1011.6056 - mean_absolute_error: 26.9034 - val_loss: 230.9415 - val_mean_absolute_error: 13.5313
# Epoch 38/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1012.3839 - mean_absolute_error: 26.9045 - val_loss: 235.9939 - val_mean_absolute_error: 13.7043
# Epoch 39/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.2020 - mean_absolute_error: 26.8681 - val_loss: 257.5446 - val_mean_absolute_error: 14.4167
# Epoch 40/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.3952 - mean_absolute_error: 26.8653 - val_loss: 270.7081 - val_mean_absolute_error: 14.8335
# Epoch 41/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.0160 - mean_absolute_error: 26.8594 - val_loss: 269.9292 - val_mean_absolute_error: 14.8092
# Epoch 42/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1010.0563 - mean_absolute_error: 26.8568 - val_loss: 263.0657 - val_mean_absolute_error: 14.5931
# Epoch 43/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.2827 - mean_absolute_error: 26.8559 - val_loss: 273.2201 - val_mean_absolute_error: 14.9116
# Epoch 44/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.2554 - mean_absolute_error: 26.8646 - val_loss: 277.0627 - val_mean_absolute_error: 15.0301
# Epoch 45/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.9042 - mean_absolute_error: 26.8571 - val_loss: 277.1778 - val_mean_absolute_error: 15.0337
# Epoch 46/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1009.9205 - mean_absolute_error: 26.8536 - val_loss: 273.8637 - val_mean_absolute_error: 14.9315
# Epoch 47/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.0298 - mean_absolute_error: 26.8612 - val_loss: 276.4545 - val_mean_absolute_error: 15.0115
# Epoch 48/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1009.8621 - mean_absolute_error: 26.8583 - val_loss: 272.4685 - val_mean_absolute_error: 14.8883
# Epoch 49/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1009.8077 - mean_absolute_error: 26.8550 - val_loss: 271.9582 - val_mean_absolute_error: 14.8724
# Epoch 50/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1004.6891 - mean_absolute_error: 26.7840 - val_loss: 334.3260 - val_mean_absolute_error: 16.8841
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 947.6409 - mean_absolute_error: 26.0680 - val_loss: 261.7359 - val_mean_absolute_error: 14.5588
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 929.3129 - mean_absolute_error: 25.6534 - val_loss: 533.8654 - val_mean_absolute_error: 22.0510
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 869.0670 - mean_absolute_error: 24.9562 - val_loss: 283.0453 - val_mean_absolute_error: 15.2978
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 835.5082 - mean_absolute_error: 24.4355 - val_loss: 282.4734 - val_mean_absolute_error: 15.3400
# Epoch 55/100
# 7/7 [==============================] - 0s 9ms/step - loss: 801.7045 - mean_absolute_error: 23.8365 - val_loss: 196.4716 - val_mean_absolute_error: 12.3666
# Epoch 56/100
# 7/7 [==============================] - 0s 11ms/step - loss: 802.4566 - mean_absolute_error: 23.9745 - val_loss: 205.7089 - val_mean_absolute_error: 12.7484
# Epoch 57/100
# 7/7 [==============================] - 0s 15ms/step - loss: 763.9304 - mean_absolute_error: 23.3400 - val_loss: 321.1165 - val_mean_absolute_error: 16.6451
# Epoch 58/100
# 7/7 [==============================] - 0s 10ms/step - loss: 750.6812 - mean_absolute_error: 23.0579 - val_loss: 354.1584 - val_mean_absolute_error: 17.6437
# Epoch 59/100
# 7/7 [==============================] - 0s 11ms/step - loss: 741.8986 - mean_absolute_error: 22.9283 - val_loss: 411.1274 - val_mean_absolute_error: 19.1999
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 725.4181 - mean_absolute_error: 22.7872 - val_loss: 162.7739 - val_mean_absolute_error: 11.1356
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 684.4968 - mean_absolute_error: 22.1387 - val_loss: 183.2742 - val_mean_absolute_error: 12.0197
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 657.1562 - mean_absolute_error: 21.4364 - val_loss: 151.4798 - val_mean_absolute_error: 10.7269
# Epoch 63/100
# 7/7 [==============================] - 0s 10ms/step - loss: 635.9084 - mean_absolute_error: 21.1893 - val_loss: 191.6491 - val_mean_absolute_error: 12.3908
# Epoch 64/100
# 7/7 [==============================] - 0s 15ms/step - loss: 603.3640 - mean_absolute_error: 20.4589 - val_loss: 173.9670 - val_mean_absolute_error: 11.7276
# Epoch 65/100
# 7/7 [==============================] - 0s 16ms/step - loss: 575.3672 - mean_absolute_error: 20.1372 - val_loss: 321.9846 - val_mean_absolute_error: 16.8551
# Epoch 66/100
# 7/7 [==============================] - 0s 12ms/step - loss: 542.5828 - mean_absolute_error: 19.3823 - val_loss: 221.1572 - val_mean_absolute_error: 13.5602
# Epoch 67/100
# 7/7 [==============================] - 0s 14ms/step - loss: 491.4699 - mean_absolute_error: 18.6379 - val_loss: 79.6885 - val_mean_absolute_error: 7.2869
# Epoch 68/100
# 7/7 [==============================] - 0s 12ms/step - loss: 468.5094 - mean_absolute_error: 18.1076 - val_loss: 118.1715 - val_mean_absolute_error: 9.3218
# Epoch 69/100
# 7/7 [==============================] - 0s 16ms/step - loss: 406.4441 - mean_absolute_error: 16.6179 - val_loss: 136.9348 - val_mean_absolute_error: 10.2719
# Epoch 70/100
# 7/7 [==============================] - 0s 15ms/step - loss: 374.8345 - mean_absolute_error: 16.0306 - val_loss: 115.2857 - val_mean_absolute_error: 9.2536
# Epoch 71/100
# 7/7 [==============================] - 0s 14ms/step - loss: 335.9583 - mean_absolute_error: 14.7704 - val_loss: 63.3832 - val_mean_absolute_error: 6.4422
# Epoch 72/100
# 7/7 [==============================] - 0s 14ms/step - loss: 288.7476 - mean_absolute_error: 13.8696 - val_loss: 43.1621 - val_mean_absolute_error: 5.2841
# Epoch 73/100
# 7/7 [==============================] - 0s 14ms/step - loss: 249.9665 - mean_absolute_error: 12.6206 - val_loss: 37.1296 - val_mean_absolute_error: 5.0793
# Epoch 74/100
# 7/7 [==============================] - 0s 12ms/step - loss: 230.5372 - mean_absolute_error: 12.2657 - val_loss: 33.7021 - val_mean_absolute_error: 4.9868
# Epoch 75/100
# 7/7 [==============================] - 0s 14ms/step - loss: 191.9766 - mean_absolute_error: 10.8724 - val_loss: 47.5308 - val_mean_absolute_error: 5.6150
# Epoch 76/100
# 7/7 [==============================] - 0s 14ms/step - loss: 152.6122 - mean_absolute_error: 9.2297 - val_loss: 35.5951 - val_mean_absolute_error: 5.1007
# Epoch 77/100
# 7/7 [==============================] - 0s 11ms/step - loss: 130.0676 - mean_absolute_error: 8.4791 - val_loss: 33.3650 - val_mean_absolute_error: 4.9931
# Epoch 78/100
# 7/7 [==============================] - 0s 12ms/step - loss: 106.8123 - mean_absolute_error: 7.6220 - val_loss: 34.7765 - val_mean_absolute_error: 5.0712
# Epoch 79/100
# 7/7 [==============================] - 0s 11ms/step - loss: 95.5000 - mean_absolute_error: 7.2271 - val_loss: 32.4979 - val_mean_absolute_error: 4.9448
# Epoch 80/100
# 7/7 [==============================] - 0s 11ms/step - loss: 75.6166 - mean_absolute_error: 6.3438 - val_loss: 46.0041 - val_mean_absolute_error: 5.4429
# Epoch 81/100
# 7/7 [==============================] - 0s 13ms/step - loss: 76.6631 - mean_absolute_error: 6.8161 - val_loss: 65.7391 - val_mean_absolute_error: 6.5038
# Epoch 82/100
# 7/7 [==============================] - 0s 11ms/step - loss: 66.1293 - mean_absolute_error: 6.2561 - val_loss: 33.4429 - val_mean_absolute_error: 4.8682
# Epoch 83/100
# 7/7 [==============================] - 0s 11ms/step - loss: 49.9537 - mean_absolute_error: 5.1634 - val_loss: 33.0399 - val_mean_absolute_error: 4.8544
# Epoch 84/100
# 7/7 [==============================] - 0s 11ms/step - loss: 44.0698 - mean_absolute_error: 4.8388 - val_loss: 32.9808 - val_mean_absolute_error: 4.8316
# Epoch 85/100
# 7/7 [==============================] - 0s 12ms/step - loss: 39.7191 - mean_absolute_error: 4.6185 - val_loss: 40.3808 - val_mean_absolute_error: 5.1799
# Epoch 86/100
# 7/7 [==============================] - 0s 10ms/step - loss: 37.1901 - mean_absolute_error: 4.5340 - val_loss: 42.5260 - val_mean_absolute_error: 5.3087
# Epoch 87/100
# 7/7 [==============================] - 0s 12ms/step - loss: 37.8744 - mean_absolute_error: 4.7751 - val_loss: 31.9360 - val_mean_absolute_error: 4.7320
# Epoch 88/100
# 7/7 [==============================] - 0s 11ms/step - loss: 35.4647 - mean_absolute_error: 4.5192 - val_loss: 42.3248 - val_mean_absolute_error: 5.3174
# Epoch 89/100
# 7/7 [==============================] - 0s 10ms/step - loss: 32.6713 - mean_absolute_error: 4.3849 - val_loss: 32.2903 - val_mean_absolute_error: 4.7142
# Epoch 90/100
# 7/7 [==============================] - 0s 11ms/step - loss: 33.3999 - mean_absolute_error: 4.4977 - val_loss: 39.8065 - val_mean_absolute_error: 5.1537
# Epoch 91/100
# 7/7 [==============================] - 0s 13ms/step - loss: 30.0839 - mean_absolute_error: 4.3143 - val_loss: 49.4968 - val_mean_absolute_error: 5.7603
# Epoch 92/100
# 7/7 [==============================] - 0s 10ms/step - loss: 30.1766 - mean_absolute_error: 4.1814 - val_loss: 34.9074 - val_mean_absolute_error: 4.8310
# Epoch 93/100
# 7/7 [==============================] - 0s 13ms/step - loss: 27.1138 - mean_absolute_error: 4.1749 - val_loss: 33.2529 - val_mean_absolute_error: 4.7015
# Epoch 94/100
# 7/7 [==============================] - 0s 13ms/step - loss: 29.9150 - mean_absolute_error: 4.3955 - val_loss: 38.6968 - val_mean_absolute_error: 5.0599
# Epoch 95/100
# 7/7 [==============================] - 0s 9ms/step - loss: 25.7041 - mean_absolute_error: 3.9514 - val_loss: 54.1176 - val_mean_absolute_error: 6.0081
# Epoch 96/100
# 7/7 [==============================] - 0s 10ms/step - loss: 25.7004 - mean_absolute_error: 3.9655 - val_loss: 56.5896 - val_mean_absolute_error: 6.1488
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 23.5936 - mean_absolute_error: 3.8712 - val_loss: 32.9786 - val_mean_absolute_error: 4.6740
# Epoch 98/100
# 7/7 [==============================] - 0s 12ms/step - loss: 25.0062 - mean_absolute_error: 3.8741 - val_loss: 33.9680 - val_mean_absolute_error: 4.7137
# Epoch 99/100
# 7/7 [==============================] - 0s 12ms/step - loss: 23.0336 - mean_absolute_error: 3.7814 - val_loss: 48.1270 - val_mean_absolute_error: 5.7333
# Epoch 100/100
# 7/7 [==============================] - 0s 12ms/step - loss: 25.7907 - mean_absolute_error: 4.0518 - val_loss: 105.9789 - val_mean_absolute_error: 8.7216

# %%
train_predictions = model.predict(X_train)
train_predictions.shape
# Out:
# 7/7 [==============================] - 1s 3ms/step
# (201, 1)

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 7ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
